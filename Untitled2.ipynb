# %%
pip install transformers

# %%
from transformers import T5ForConditionalGeneration, AutoTokenizer

checkpoint = "Salesforce/codet5p-220m-py"
device = "cuda" # for GPU usage or "cpu" for CPU usage

tokenizer = AutoTokenizer.from_pretrained(checkpoint)
model = T5ForConditionalGeneration.from_pretrained(checkpoint).to(device)
# Out:
# Downloading (…)okenizer_config.json:   0%|          | 0.00/1.48k [00:00<?, ?B/s]
# Downloading (…)olve/main/vocab.json:   0%|          | 0.00/703k [00:00<?, ?B/s]
# Downloading (…)olve/main/merges.txt:   0%|          | 0.00/294k [00:00<?, ?B/s]
# Downloading (…)in/added_tokens.json:   0%|          | 0.00/2.00 [00:00<?, ?B/s]
# Downloading (…)cial_tokens_map.json:   0%|          | 0.00/12.5k [00:00<?, ?B/s]
# Downloading (…)lve/main/config.json:   0%|          | 0.00/771 [00:00<?, ?B/s]
# Downloading pytorch_model.bin:   0%|          | 0.00/446M [00:00<?, ?B/s]

# %%
inputs = tokenizer.encode("write python code for print one to 10", return_tensors="pt").to(device)
outputs = model.generate(inputs, max_length=1000)
print(tokenizer.decode(outputs[0], skip_special_tokens=True))
# Out:
# for i in range(1,11):
#     print(i)
